# %% [markdown]
# # Intro to Probability

# %% [markdown]
# Probability plays a vital role in data analytics by offering a mathematical foundation to measure uncertainty, enabling informed decision-making, and evaluating the chances of different outcomes. This is essential for conducting rigorous statistical analyses and developing accurate predictive models.

# %% [markdown]
# ## Set Theory

# %% [markdown]
# In set theory we represent the "union" of two sets A and B with$A \cup B$, which represents all the members from both sets. We should keep in mind that if both sets A, and B have common elements, $A \cup B$ will contain duplicated elements.
#
# In contrast, we name the "intersection" of two sets A and B with $A \cap B$, which represent the "common" elements to both sets.

# %% [markdown]
# #### Example 1

# %% [markdown]
# Set theory, an important part of mathematics, studies unique groups of elements. This lays the essential groundwork for understanding probability. Grasping sets is vital for exploring the world of probability.

# %% [markdown]
# - Lets consider two sets, A and B ,where:
#     - A represents Students IDs who passed Mathematics
#     - B representes Students IDs who passed English

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
A = {1001, 1002, 1004, 1005, 1006, 1008, 1010}
B = {1003, 1004, 1005, 1006, 1007, 1008, 1009}

# %%
#Students who passed math or English or both
A.union(B)
# Out:
# {1001, 1002, 1003, 1004, 1005, 1006, 1007, 1008, 1009, 1010}

# %%
#Students who passed both subjects
A.intersection(B)
# Out:
# {1004, 1005, 1006, 1008}

# %%
#Students who passed math but not English
A.difference(B)
# Out:
# {1001, 1002, 1010}

# %%
#Students who passed English but not math
B.difference(A)
# Out:
# {1003, 1007, 1009}

# %% [markdown]
# ## Probability

# %% [markdown]
# How to **estimate** probabilities? (frequentist approach)
#
# $$P(x) = \frac{nx}{total}$$
#
# Flips = 15
# Heads = 7
# Tails = 8
#
# $$P(H) = \frac{7}{15}$$
# $$P(T) = \frac{8}{15}$$
# $$P(H) \ne P(T)$$

# %% [markdown]
# $$P_{real}(H) = P(H) + \delta(flips)$$
#
# $$\delta(flips) \propto \frac{1}{flips}$$

# %% [markdown]
# ### Example 2

# %% [markdown]
# Drawing Cards

# %% [markdown]
# - 1. What is the probability of drawing an Ace from a standard deck of 52 cards?
# - 2. What is the probability of drawing either a red card or a Queen from a standard deck of 52 cards?
# - 3. If you draw a card from a standard deck and it is red, what is the probability that it is a King?

# %%
#1.
# S = {all 52 cards}
# A = {ace_spades, ace_hearts, ace_diamonds, aces_clubs}

# P(Ace) = 4/52

#A standard deck has 52 cards
deck = 52

#A standard deck has 4 aces
aces = 4

probability_aces = aces/deck

print(f"The probability of drawing an Ace is {probability_aces : .2f}")
# Out:
# The probability of drawing an Ace is  0.08

# %% [markdown]
# OR  -> +
# AND -> *

# %%
#2. #P(Red) = 1/2; P(Queen) = 4/52
# Sample_space_red_cards = {red_cards}
# Sample_space_queens = {queen_of_hearts, queen_of_diamonds, queen_of_clubs, queen_of...}
#P(Red ∪ Queen) = P(Red) * P(Queen) - P(Red ∩ Queen) # We need to substract the intersection to avoid counting twice the same cards
#P(Red ∪ Queen) = 26/52 * 4/52 - 2/52 # We have que Queen of diamonds, and the Queen of hearts.
p_red_or_queen = (26/52) + (4/52) - (2/52)

print(f"The probability of drawing a Queen or a red card is {p_red_or_queen: .3f}")
# Out:
# The probability of drawing a Queen or a red card is  0.538

# %%
#3.
# Among the red cards, what is the probability to select a King?
#P(King|Red) = P(King ∩ Red) / P(Red)
#P(King|Red) = P(Red|King) * P(King) / P(Red) = (2/4) * (4/52) / (26/52)
p_king_after_red = (2/4) * (4/52) / (1/2) #(2/52) / (26/52)
print(f"The probability of drawing a King, knowing its red card is {p_king_after_red: .2f}")
# Out:
# The probability of drawing a King, knowing its red card is  0.08

# %% [markdown]
# ### Example 3

# %% [markdown]
# You are planning to go on a picnic today but the morning is cloudy. You hate rain so you don't know whether to go out or stay home! To help you make a decision, you gather the following data about rainy days:
#
# - Knowing that it is a rainy day, the probability of cloudy is 50%!
# - The probability of any day (rainy or not) starting off cloudy is 40%.
# - This month is usually dry so only 3 of 30 days (10%) tend to be rainy.
# - What is the probability of rain, given the day started cloudy?

# %% [markdown]
# **Baye's Theorem**
#
# $$P(x, y)=?$$
#
# $$P(x),P(y)$$
#
# $$P(x, y) = P(x)*P(y|x)$$
# $$P(x, y) = P(y)*P(x|y)$$
#
# $$P(x)*P(y|x) = P(y)*P(x|y)$$
#
# $$P(x|y) = \frac{P(x)*P(y|x)}{P(y)}$$

# %%
# Bayes Theorem is going to be really usefull here if we have in consideration that available data

# P(C|R) = 0.5
# P(C) = 0.4
# P(R) = 0.1

# P(R|C) = P(R) * P(C|R) / P(C)

p_cr = 0.5 # P(C|R)
p_c = 0.4 # P(C)
p_r = 0.1 # P(R)

p_rc = (p_r * p_cr) / p_c

print(f"The probability that it's rainny when it's cloudy is {p_rc: .2f}")
# Out:
# The probability that it's rainny when it's cloudy is  0.12

# %% [markdown]
# ## Probability Distributions

# %% [markdown]
# #### Discrete

# %% [markdown]
# ##### **Binomial Distribution** - Probability of having k successes in n independent trials with individual success probability p.

# %% [markdown]
# The idea here is the following:
#
# We're dealing with an experiment that can only take **TWO** possible outcomes (no matter which ones, what matters it to have only two possible values). Then, we wonder what is the probability that if we repeat the experiment "n" times, we will get "k" succefull events.
#
# Examples:
#
# * Flipping a coin, we can have heads "H" or tails "T".
# * Online transactions, it can be fraudulent "F" or not "N".
#
# What we consider "successful" event can be any of the two outcomes.
# On the other hand, the individual probabilites doesn't matter here. The coin can be fair or not, online transactions are mostly not fraudulent.

# %% [markdown]
# - Let's thing about this example:
# - Before the vaccines were released by companies, the government had to contact some suppliers in order to vaccinate the entire population when the vaccines were ready. So, imagine that each company had a probability of developing the vaccine of 40%.
# - Each supplier has the capacity to develop 10,000 vaccines.
# - The population that needs to be administered the vaccine is 30,000 people
#
# **How many suppliers should the government contract?**
#
# Let's say the goverment contracts with 10 labs.
# Is this enough to vacinate this 30000 people?

# %% [markdown]
# $$Binom(k, n,p) = C(n, k) * p^{k} * (1 - p)^{n-k} $$
#
# $$C(n, k) = \frac{n!}{k!(n-k)!}$$
#
# $$n! = n * ( n - 1 ) * (n - 2 ) .... 1$$

# %%
from scipy.stats import binom

n = 10
p = 0.40
binom_dist = binom(n,p)

# If each lab can provide 10K vaccines and we have 30K people, we will need to contact at least 30K/10K = 3 or more successful labs.

# Let's see what is the probability to contact 3 successful labs.
print(f"The probability to have 3 successful contacts when we reach 10 labs is: {binom.pmf(3, n, p): .2f}")

# However, if we have 3 or more (in any amount) successful contacts will also be safe. Lets compute what is the probability of
# finding 4 successful labs if we contact 10.
print(f"The probability to have 4 successful contacts when we reach 10 labs is: {binom.pmf(4, n, p): .2f}")

# finding 5 successful labs if we contact 10.
print(f"The probability to have 5 successful contacts when we reach 10 labs is: {binom.pmf(5, n, p): .2f}")

# finding 6 successful labs if we contact 10.
print(f"The probability to have 6 successful contacts when we reach 10 labs is: {binom.pmf(6, n, p): .2f}")

# finding 7 successful labs if we contact 10.
print(f"The probability to have 7 successful contacts when we reach 10 labs is: {binom.pmf(7, n, p): .2f}")

# finding 8 successful labs if we contact 10.
print(f"The probability to have 8 successful contacts when we reach 10 labs is: {binom.pmf(8, n, p): .2f}")

# finding 9 successful labs if we contact 10.
print(f"The probability to have 9 successful contacts when we reach 10 labs is: {binom.pmf(9, n, p): .2f}")

# finding 10 successful labs if we contact 10.
print(f"The probability to have 10 successful contacts when we reach 10 labs is: {binom.pmf(10, n, p): .2f}")

total_probability = 0
for k in range(3,11):
    total_probability += binom.pmf(k, n, p)

print(f"The probability to have 3 or more successful contacts when we reach 10 labs is: {total_probability: .4f}")

#binom_dist.cdf(2) = P(k=0, n, p) + P(k=1, n, p ) + P(k=2, n, p)
1 - binom_dist.cdf(2) # 1 - [ P(k=0, n=10, p) + P(k=1, n=10, p) + P(k=2, n=10, p) ]
# Out:
# The probability to have 3 successful contacts when we reach 10 labs is:  0.21
# The probability to have 4 successful contacts when we reach 10 labs is:  0.25
# The probability to have 5 successful contacts when we reach 10 labs is:  0.20
# The probability to have 6 successful contacts when we reach 10 labs is:  0.11
# The probability to have 7 successful contacts when we reach 10 labs is:  0.04
# The probability to have 8 successful contacts when we reach 10 labs is:  0.01
# The probability to have 9 successful contacts when we reach 10 labs is:  0.00
# The probability to have 10 successful contacts when we reach 10 labs is:  0.00
# The probability to have 3 or more successful contacts when we reach 10 labs is:  0.8327
# np.float64(0.8327102464)

# %% [markdown]
# In this problem we don't care how many successful contacts we have as long as we hit 3 or more. Therefore, we're looking for:
#
# $$P(k \ge 3, n, p) = \sum_{k=3}^{10}P(k, n, p) = P(3, 10, 0.4) + P(4, 10, 0.4) + P(5, 10, 0.4) +...+ P(10, 10, 0.4)$$
#
# This is called the "acumulated probability". We need to add the individual probabilities because we can reach our goal in several ways: with 3 successful contacts, with 4, 5,...and so on.
#
# This probability can be also computed as the 1 - probability of having less than 2 sucessful contacts: ie:
#
# $$ 1 - P(k < 3, n, p) = 1 - \sum_{k=0}^{2}P(k, n, p)= 1 -( P(0, 10, 0.4) + P(1, 10, 0.4) + P(2, 10, 0.4))$$
#
# Let's compute what we want.

# %%
cumulated_probability = 0
for k in range(3,11):
    cumulated_probability += binom.pmf(k, n, p)

print(f"The probability to have 3 or more successful contacts when we reach 10 labs is: {cumulated_probability: .2f}")
# Out:
# The probability to have 3 or more successful contacts when we reach 10 labs is:  0.83

# %% [markdown]
# This last probability is called the cumulated probability up to 2, usually called CDF(2).

# %%
print(f"The probability to have 3 or more successful contacts when we reach 10 labs is: {1 - binom.cdf(2, n, p): .2f}")
# Out:
# The probability to have 3 or more successful contacts when we reach 10 labs is:  0.83

# %% [markdown]
# If instead of contacting 10 labs, we contact 15...

# %%
n = 15
p = 0.40
binom_dist = binom(n,p)
cumulated_probability = 0
for k in range(3,16):
    cumulated_probability += binom.pmf(k, n, p)

print(cumulated_probability)
1- binom_dist.cdf(2)
# Out:
# 0.9728859992227844
# np.float64(0.972885999222784)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

n=15
fig, axes = plt.subplots(1,2, figsize=(15,6), sharey=True)
sns.barplot(x=[i for i in range(n+1)], y=[ binom.pmf(k, 10, p) for k in range(n+1)],ax=axes[0]);
axes[0].set_xlabel("Number of labs")
axes[0].set_ylabel("Probability")
axes[0].set_title("Contacting 10 labs")
sns.barplot(x=[i for i in range(n+1)], y=[ binom.pmf(k, 15, p) for k in range(n+1)], ax=axes[1]);
axes[1].set_xlabel("Number of labs")
axes[1].set_ylabel("Probability")
axes[1].set_title("Contacting 15 labs")

plt.tight_layout()
plt.show()

# %% [markdown]
# We can say that if we contract 15 labs, the probability of three or more labs being successful in the development of the vaccine is now 0.97.
# - Is this enough? Of course, the more labs we contract, the better. However, there are costs associated with contracting labs that we need to take into consideration

# %% [markdown]
# ##### **Geometric Distribution**

# %% [markdown]
# Suppose you are applying for jobs, and the probability of receiving an interview invitation for each job application is p = 0.20.
# Calculate the probability of getting an interview invitation on the third job application.

# %%
from scipy.stats import geom

p = 0.20
geom_dist = geom(p)

print(f"The probability to get an interview invitation exactly on the 3rd job application is {geom_dist.pmf(3): .2f}")
# Out:
# The probability to get an interview invitation exactly on the 3rd job application is  0.13

# %%
sns.barplot(x=[i for i in range(n+1)], y=[ geom_dist.pmf(k) for k in range(n+1)]);

# %% [markdown]
# What is the probability that they need to submit at least 5 job applications before receiving their first job offer?

# %%
print(f"The probability to get an interview invitation after the 5th job application is {1 - geom_dist.cdf(4): .2f}")
# Out:
# The probability to get an interview invitation after the 5th job application is  0.41

# %% [markdown]
# ##### **Poisson Distribution**

# %% [markdown]
# It's used when we're looking for counting events in  given period of time.

# %% [markdown]
# Suppose that on average, there are 2 accidents per day at a certain intersection.
#
# - What is the probability that there will be no accidents at the intersection tomorrow?

# %%
from scipy.stats import poisson

mu = 2 # average
poisson_dist = poisson(mu)

print(f"The probability that tomorrow we dont observe an accident is {poisson_dist.pmf(0): .2f}")
# Out:
# The probability that tomorrow we dont observe an accident is  0.14

# %% [markdown]
# - What is the probability that there will be at least 5 accidents at the intersection tomorrow?

# %%
print(f"The probability that tomorrow we observe 5 or more accidents is {1 - poisson_dist.cdf(4): .2f}")
# Out:
# The probability that tomorrow we observe 5 or more accidents is  0.05

# %% [markdown]
# #### Continuous

# %% [markdown]
# ##### **Exponencial Distribution**

# %% [markdown]
# Suppose the time (in minutes) between two consecutive arrivals at a bus stop is 10min.
#
# - Calculate the probability that the time between arrivals is less than 8 minutes.

# %%
from scipy.stats import expon

#the parameter represents the rate of events occuring per unit of time
lambda_value = 0.1 # 1 bus / 10mins

lambda_inv = expon(scale = 1/lambda_value)

lambda_inv.cdf(8)
# Out:
# np.float64(0.5506710358827784)

# %% [markdown]
# - Calculate the probability that the time between arrivals is more than 15 minutes.

# %%
print(f"The probability that the time between arrivals is more than 15 minutes is {1 - lambda_inv.cdf(15): .2f}")
# Out:
# The probability that the time between arrivals is more than 15 minutes is  0.22

# %% [markdown]
# ##### **Normal (Gaussian) Distribution**

# %% [markdown]
# Suppose the heights of a population of students follow a normal distribution with a mean (μ) of 175 cm and a standard deviation (σ) of 7.5 cm .
#
# - What is the probability that a randomly selected student is taller than 182 cm?

# %%
from scipy.stats import norm

mean = 175
std = 7.5

norm_dist = norm(loc = mean, scale = std)
print(f"The probability of the student's height being greater than 182 cm is {1 - norm_dist.cdf(182): .2f}")
# Out:
# The probability of the student's height being greater than 182 cm is  0.18

# %% [markdown]
# - What is the probability that the height of a randomly selected student is between 170cm and 175cm?

# %% [markdown]
# $$P(170 <= h <= 175)=? = P(h < 175) - P(h < 170) =  CDF(175) - CDF(170)$$

# %%
print(f"The probability of the student's height being between 170 cm and 175 cm is {norm_dist.cdf(175) - norm_dist.cdf(170): .2f}")
# Out:
# The probability of the student's height being between 170 cm and 175 cm is  0.25

# %% [markdown]
# The CDF(x) is the sum of all the probabilities from smallest value to x.
#
# 1 = CDF(x) + "remains"
